# %%
import os
import random
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import cv2
from tensorflow import keras
import tensorflow as tf
import keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Dropout, Activation, SimpleRNN
from tensorflow.keras.layers import BatchNormalization, Reshape, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from PIL import Image
from PIL import UnidentifiedImageError

from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import itertools
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')
from sklearn import metrics
from sklearn.preprocessing import label_binarize
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
#upright = os.listdir(r'/content/drive/MyDrive/posture/Upright Sitting')
#Crossed_legs = os.listdir(r'/content/drive/MyDrive/posture/Crossing legs')
#slant_bending = os.listdir(r'/content/drive/MyDrive/posture/Slant Bending')
#Lordosis = os.listdir(r'/content/drive/MyDrive/posture/Lordosis')
#slouching = os.listdir(r'/content/drive/MyDrive/posture/Slouching')

#Sitting_Posture = os.listdir('C:/Users/Dell/Desktop/Sitting_Posture')
bending = os.listdir('C:/Users/Dell/Desktop/Human_posture/bending')
lying = os.listdir('C:/Users/Dell/Desktop/Human_posture/lying')
sitting = os.listdir('C:/Users/Dell/Desktop/Human_posture/sitting')
standing = os.listdir('C:/Users/Dell/Desktop/Human_posture/standing')

# %%
img_w, img_h = 150, 150 #setting the image width and height for easy processing
X = []
y = []

for i in bending:
    try:
        img = Image.open("C:/Users/Dell/Desktop/Human_posture/bending/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(0)
    except UnidentifiedImageError: # it passes an image that wasn't correctly identified
        pass
    
for i in lying:
    try:
        img = Image.open("C:/Users/Dell/Desktop/Human_posture/lying/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(1)
    except UnidentifiedImageError:
        pass
    
for i in sitting:
    try:
        img = Image.open("C:/Users/Dell/Desktop/Human_posture/sitting/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(2)
    except UnidentifiedImageError:
        pass
    
for i in standing:
    try:
        img = Image.open("C:/Users/Dell/Desktop/Human_posture/standing/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(3)
    except UnidentifiedImageError:
        pass
    
    
    

X = np.asarray(X)
y = np.asarray(y)
print(X.shape, y.shape)

# I resized each image to our manually defined width and height(img_w, img_h)
# I also changed the images to an array
# Out:
# (4800, 150, 150, 3) (4800,)

# %%
x = X.astype('float32')
x /= 255

#scaler = MinMaxScaler()
#x = scaler.fit_transform(x)

num_classes = 4

labels = keras.utils.to_categorical(y, num_classes)
print(labels[0])
# Out:
# [1. 0. 0. 0.]

# %%
# splitting our dataset into train and test
x_train1, x_test, y_train1, y_test = train_test_split(x, labels, test_size = 0.2, random_state=5)
x_train,x_val,y_train,y_val=train_test_split(x_train1,y_train1,test_size=0.2,random_state=5)


print('Number of train: {}'.format(len(x_train)))
print('Number of validation: {}'.format(len(x_val)))
print('Number of test: {}'.format(len(x_test)))
# Out:
# Number of train: 3072
# Number of validation: 768
# Number of test: 960

# %%
datagen = ImageDataGenerator(
    rotation_range=20.,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=30.,
    zoom_range=0.2,
    horizontal_flip=0.2,
    rescale=None)

datagen.fit(x_train)

# %%
ICV1_1 = tf.keras.applications.InceptionV3(input_shape=(150,150,3),include_top=False,weights="imagenet")

# %%
for layer in ICV1_1.layers:
    layer.trainable=False

# %%
import os
import random

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import cv2
from tensorflow import keras
import tensorflow as tf
import keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Dropout, Activation, SimpleRNN
from tensorflow.keras.layers import BatchNormalization, Reshape, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from PIL import Image
from PIL import UnidentifiedImageError

from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import itertools
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')
from sklearn import metrics
from sklearn.preprocessing import label_binarize
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
# My neural network consists of 3 layers densely connected
# dropout helps prevent over fitting of the model when testing it
model_Inception=Sequential()
model_Inception.add(ICV1_1)
model_Inception.add(Flatten())
model_Inception.add(Dense(128, activation='relu'))
model_Inception.add(Dropout(0.5))
model_Inception.add(Dense(128, activation='relu'))
model_Inception.add(Dropout(0.5))
model_Inception.add(Dense(4, activation='linear'))
model_Inception.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 128)               2359424
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 24,179,236
# Trainable params: 2,376,452
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
# here i am defining my performance metrics to check the performance of the model
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
lrd = ReduceLROnPlateau(monitor = 'recall',patience = 10,verbose = 1,factor = 0.70, min_lr = 1e-5)
# the above line of code reduces the learning rate when there is no improvement to the metric
# i added this line of code because i trained the model without it and the performance was stagnant
# the performance was stuck on 0.96nnn as the accuracy so i added the line of code to reduce
# the learing rate after two epochs
mcp = ModelCheckpoint('model.h5')
es = EarlyStopping(verbose=1, patience=20)

model_Inception.compile(optimizer='adam', loss = 'hinge', metrics = ['accuracy'])

# %%
# this is where i fit and trained my model
# %time
history=model_Inception.fit(x_train,y_train,validation_data=(x_val,y_val),epochs = 50,verbose = 1, callbacks=[lrd,mcp,es])
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Epoch 1/50
# 96/96 [==============================] - ETA: 0s - loss: 10.2692 - accuracy: 0.4535WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 194s 2s/step - loss: 10.2692 - accuracy: 0.4535 - val_loss: 0.3040 - val_accuracy: 0.7826 - lr: 0.0010
# Epoch 2/50
# 96/96 [==============================] - ETA: 0s - loss: 0.6310 - accuracy: 0.5921WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 171s 2s/step - loss: 0.6310 - accuracy: 0.5921 - val_loss: 0.2936 - val_accuracy: 0.8229 - lr: 0.0010
# Epoch 3/50
# 96/96 [==============================] - ETA: 0s - loss: 0.4827 - accuracy: 0.6654WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 169s 2s/step - loss: 0.4827 - accuracy: 0.6654 - val_loss: 0.2154 - val_accuracy: 0.8385 - lr: 0.0010
# Epoch 4/50
# 96/96 [==============================] - ETA: 0s - loss: 0.4061 - accuracy: 0.6517WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 172s 2s/step - loss: 0.4061 - accuracy: 0.6517 - val_loss: 0.2452 - val_accuracy: 0.7695 - lr: 0.0010
# Epoch 5/50
# 96/96 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.6836WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 169s 2s/step - loss: 0.3364 - accuracy: 0.6836 - val_loss: 0.1742 - val_accuracy: 0.8060 - lr: 0.0010
# Epoch 6/50
# 96/96 [==============================] - ETA: 0s - loss: 0.3118 - accuracy: 0.6973WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 171s 2s/step - loss: 0.3118 - accuracy: 0.6973 - val_loss: 0.1574 - val_accuracy: 0.8854 - lr: 0.0010
# Epoch 7/50
# 96/96 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.6719WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.3176 - accuracy: 0.6719 - val_loss: 0.2350 - val_accuracy: 0.8789 - lr: 0.0010
# Epoch 8/50
# 96/96 [==============================] - ETA: 0s - loss: 0.3296 - accuracy: 0.6712WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 170s 2s/step - loss: 0.3296 - accuracy: 0.6712 - val_loss: 0.1893 - val_accuracy: 0.8659 - lr: 0.0010
# Epoch 9/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2897 - accuracy: 0.6842WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 169s 2s/step - loss: 0.2897 - accuracy: 0.6842 - val_loss: 0.1547 - val_accuracy: 0.8763 - lr: 0.0010
# Epoch 10/50
# 96/96 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.6706WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.3029 - accuracy: 0.6706 - val_loss: 0.1761 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 11/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.6999WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 171s 2s/step - loss: 0.2717 - accuracy: 0.6999 - val_loss: 0.1435 - val_accuracy: 0.8815 - lr: 0.0010
# Epoch 12/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2830 - accuracy: 0.6865WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 170s 2s/step - loss: 0.2830 - accuracy: 0.6865 - val_loss: 0.1624 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 13/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2811 - accuracy: 0.6927WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 171s 2s/step - loss: 0.2811 - accuracy: 0.6927 - val_loss: 0.1786 - val_accuracy: 0.8802 - lr: 0.0010
# Epoch 14/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.7041WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2605 - accuracy: 0.7041 - val_loss: 0.1656 - val_accuracy: 0.8867 - lr: 0.0010
# Epoch 15/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.7067WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 170s 2s/step - loss: 0.2692 - accuracy: 0.7067 - val_loss: 0.1209 - val_accuracy: 0.9036 - lr: 0.0010
# Epoch 16/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2532 - accuracy: 0.7015WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2532 - accuracy: 0.7015 - val_loss: 0.1649 - val_accuracy: 0.8880 - lr: 0.0010
# Epoch 17/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2569 - accuracy: 0.7067WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2569 - accuracy: 0.7067 - val_loss: 0.1835 - val_accuracy: 0.8711 - lr: 0.0010
# Epoch 18/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2499 - accuracy: 0.7051WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2499 - accuracy: 0.7051 - val_loss: 0.1408 - val_accuracy: 0.8789 - lr: 0.0010
# Epoch 19/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2417 - accuracy: 0.7174WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 170s 2s/step - loss: 0.2417 - accuracy: 0.7174 - val_loss: 0.1323 - val_accuracy: 0.9010 - lr: 0.0010
# Epoch 20/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2325 - accuracy: 0.7389WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2325 - accuracy: 0.7389 - val_loss: 0.1310 - val_accuracy: 0.9049 - lr: 0.0010
# Epoch 21/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2417 - accuracy: 0.7243WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 169s 2s/step - loss: 0.2417 - accuracy: 0.7243 - val_loss: 0.1217 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 22/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.7311WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 167s 2s/step - loss: 0.2329 - accuracy: 0.7311 - val_loss: 0.1427 - val_accuracy: 0.8971 - lr: 0.0010
# Epoch 23/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2255 - accuracy: 0.7227WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2255 - accuracy: 0.7227 - val_loss: 0.1441 - val_accuracy: 0.8646 - lr: 0.0010
# Epoch 24/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2279 - accuracy: 0.7240WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 169s 2s/step - loss: 0.2279 - accuracy: 0.7240 - val_loss: 0.1406 - val_accuracy: 0.8854 - lr: 0.0010
# Epoch 25/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2229 - accuracy: 0.7295WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 167s 2s/step - loss: 0.2229 - accuracy: 0.7295 - val_loss: 0.1268 - val_accuracy: 0.9115 - lr: 0.0010
# Epoch 26/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.7220WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2272 - accuracy: 0.7220 - val_loss: 0.1275 - val_accuracy: 0.8932 - lr: 0.0010
# Epoch 27/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.7266WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2293 - accuracy: 0.7266 - val_loss: 0.1235 - val_accuracy: 0.8893 - lr: 0.0010
# Epoch 28/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2159 - accuracy: 0.7350WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 171s 2s/step - loss: 0.2159 - accuracy: 0.7350 - val_loss: 0.1240 - val_accuracy: 0.9076 - lr: 0.0010
# Epoch 29/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2202 - accuracy: 0.7236WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2202 - accuracy: 0.7236 - val_loss: 0.1414 - val_accuracy: 0.8945 - lr: 0.0010
# Epoch 30/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2090 - accuracy: 0.7529WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 169s 2s/step - loss: 0.2090 - accuracy: 0.7529 - val_loss: 0.1323 - val_accuracy: 0.8971 - lr: 0.0010
# Epoch 31/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2136 - accuracy: 0.7311WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 167s 2s/step - loss: 0.2136 - accuracy: 0.7311 - val_loss: 0.1320 - val_accuracy: 0.8841 - lr: 0.0010
# Epoch 32/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.7145WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2224 - accuracy: 0.7145 - val_loss: 0.1319 - val_accuracy: 0.9076 - lr: 0.0010
# Epoch 33/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2149 - accuracy: 0.7295WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 168s 2s/step - loss: 0.2149 - accuracy: 0.7295 - val_loss: 0.1291 - val_accuracy: 0.8997 - lr: 0.0010
# Epoch 34/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.7324WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 167s 2s/step - loss: 0.2237 - accuracy: 0.7324 - val_loss: 0.1355 - val_accuracy: 0.8945 - lr: 0.0010
# Epoch 35/50
# 96/96 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.7435WARNING:tensorflow:Learning rate reduction is conditioned on metric `recall` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 96/96 [==============================] - 169s 2s/step - loss: 0.2118 - accuracy: 0.7435 - val_loss: 0.1279 - val_accuracy: 0.9115 - lr: 0.0010
# Epoch 35: early stopping

# %%
Test_data = model_Inception.evaluate(x_test, y_test)
# Out:
# 30/30 [==============================] - 33s 1s/step - loss: 0.1847 - accuracy: 0.9083

# %%
#loss
plt.style.use("ggplot")
plt.plot(history.history['loss'], 'go--', c = "blue", label='Train loss')
plt.plot(history.history['val_loss'], 'go--', c = "red", label='Val loss')
plt.title('InceptionV3 Model For loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

#accuracies
plt.plot(history.history['accuracy'], 'go--', c = "blue", label='Train accuracy')
plt.plot(history.history['val_accuracy'], 'go--', c = "red", label='Val accuracy')
plt.title('InceptionV3 Model For Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.savefig('AccuracyVal_accuracy')


plt.plot(history.history['precision'], 'go--', c = "blue", label='Precision')
plt.plot(history.history['val_precision'], 'go--', c = "red", label='Val_precision')
plt.title('Hybridized InceptionV3 and SVM Model For Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend() 
plt.show()
plt.savefig('Precision_Scores')

         
plt.plot(history.history['recall'], 'go--', c = "blue", label='Recall')
plt.plot(history.history['val_recall'], 'go--', c = "red", label='Val_Recall')
plt.title('Hybridized InceptionV3 and SVM Model For Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.savefig('Recall_Scores')



plt.plot(history.history['f1_score'], 'go--', c = "blue", label='F1_score')
plt.plot(history.history['val_f1_score'], 'go--', c = "red", label='Val_F1_score')
plt.title('Hybridized InceptionV3 and SVM Model For F1_score')
plt.ylabel('F1_score')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.savefig('F1_Score')




plt.plot(history.history['auc'], 'go--', c = "blue", label='AUC')
plt.plot(history.history['val_auc'], 'go--', c = "red", label='Val_AUC')
plt.title('Hybridized InceptionV3 and SVM Model For AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.savefig('AUC')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 23>()
#      19 plt.show()
#      20 plt.savefig('AccuracyVal_accuracy')
# ---> 23 plt.plot(history.history['precision'], 'go--', c = "blue", label='Precision')
#      24 plt.plot(history.history['val_precision'], 'go--', c = "red", label='Val_precision')
#      25 plt.title('Hybridized InceptionV3 and SVM Model For Precision')
#
# KeyError: 'precision'

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(history.history['val_loss']))
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.scatter(epochs_range, acc, label='Training Accuracy')
plt.scatter(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('InceptionV3 Model For Train and Valid Accuracy')
plt.subplot(1, 2, 2)
plt.scatter(epochs_range, loss, label='Training Loss')
plt.scatter(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('InceptionV3 Model For Train and Valid Loss')
plt.show()

# %%
# here i want to define and plot my confusion matrix
# and also my classification report
def plot_confusion_matrix(cm, classes, normalize=True, title='InceptionV3 Model Confusion matrix', cmap=plt.cm.Blues):
    
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    
y_pred = (model_Inception.predict(x_test) > 0.5).astype("int32")

y_test_c = np.argmax(y_test, axis=1)
target_names = ["bending", "lying", "sitting", "standing"]

Y_pred = np.argmax(model_Inception.predict(x_test),axis=1)
print('InceptionV3 Model Confusion Matrix')
cm = confusion_matrix(y_test_c, Y_pred)
plot_confusion_matrix(cm, target_names, normalize=False, title='InceptionV3 Model Confusion Matrix')

print('Classification Report')
print(classification_report(y_test_c, Y_pred, target_names=target_names))
# Out:
# 30/30 [==============================] - 33s 879ms/step
# 30/30 [==============================] - 23s 760ms/step
# InceptionV3 Model Confusion Matrix
# Classification Report
#               precision    recall  f1-score   support
#
#      bending       0.95      0.88      0.91       229
#        lying       0.95      0.93      0.94       242
#      sitting       0.81      0.94      0.87       247
#     standing       0.96      0.88      0.92       242
#
#     accuracy                           0.91       960
#    macro avg       0.92      0.91      0.91       960
# weighted avg       0.91      0.91      0.91       960

# %%
# here i want to define and plot my confusion matrix
# and also my classification report
def plot_confusion_matrix(cm, classes, normalize=True, title='InceptionV3 Model Confusion matrix', cmap=plt.cm.Blues):
    
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    
y_pred = (model_Inception.predict(x_test) > 0.5).astype("int32")

y_test_c = np.argmax(y_test, axis=1)
target_names = ["bending", "lying", "sitting", "standing"]

Y_pred = np.argmax(model_Inception.predict(x_test),axis=1)
print('InceptionV3 Model Confusion Matrix')
cm = confusion_matrix(y_test_c, Y_pred)
plot_confusion_matrix(cm, target_names, normalize=True, title='InceptionV3 Model Confusion Matrix')

print('Classification Report')
print(classification_report(y_test_c, Y_pred, target_names=target_names))
# Out:
# 30/30 [==============================] - 28s 872ms/step
# 30/30 [==============================] - 23s 760ms/step
# InceptionV3 Model Confusion Matrix
# Classification Report
#               precision    recall  f1-score   support
#
#      bending       0.95      0.88      0.91       229
#        lying       0.95      0.93      0.94       242
#      sitting       0.81      0.94      0.87       247
#     standing       0.96      0.88      0.92       242
#
#     accuracy                           0.91       960
#    macro avg       0.92      0.91      0.91       960
# weighted avg       0.91      0.91      0.91       960
