# %%
import os
import random
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import cv2
from tensorflow import keras
import tensorflow as tf
import keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Dropout, Activation, SimpleRNN
from tensorflow.keras.layers import BatchNormalization, Reshape, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from PIL import Image
from PIL import UnidentifiedImageError

from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import itertools
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')
from sklearn import metrics
from sklearn.preprocessing import label_binarize
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
#upright = os.listdir(r'/content/drive/MyDrive/posture/Upright Sitting')
#Crossed_legs = os.listdir(r'/content/drive/MyDrive/posture/Crossing legs')
#slant_bending = os.listdir(r'/content/drive/MyDrive/posture/Slant Bending')
#Lordosis = os.listdir(r'/content/drive/MyDrive/posture/Lordosis')
#slouching = os.listdir(r'/content/drive/MyDrive/posture/Slouching')

#Sitting_Posture = os.listdir('C:/Users/Dell/Desktop/Sitting_Posture')
bending = os.listdir('C:/Users/Dell/Desktop/Human_posture/bending')
lying = os.listdir('C:/Users/Dell/Desktop/Human_posture/lying')
sitting = os.listdir('C:/Users/Dell/Desktop/Human_posture/sitting')
standing = os.listdir('C:/Users/Dell/Desktop/Human_posture/standing')

# %%
img_w, img_h = 150, 150 #setting the image width and height for easy processing
X = []
y = []

for i in bending:
    try:
        img = Image.open("C:/Users/Dell/Desktop/Human_posture/bending/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(0)
    except UnidentifiedImageError: # it passes an image that wasn't correctly identified
        pass
    
for i in lying:
    try:
        img = Image.open("C:/Users/Dell/Desktop/Human_posture/lying/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(1)
    except UnidentifiedImageError:
        pass
    
for i in sitting:
    try:
        img = Image.open("C:/Users/Dell/Desktop/Human_posture/sitting/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(2)
    except UnidentifiedImageError:
        pass
    
for i in standing:
    try:
        img = Image.open("C:/Users/Dell/Desktop/Human_posture/standing/" + i).convert('RGB')
        img = img.resize((img_w,img_h))
        X.append(np.asarray(img))
        y.append(3)
    except UnidentifiedImageError:
        pass
    
    
    

X = np.asarray(X)
y = np.asarray(y)
print(X.shape, y.shape)

# I resized each image to our manually defined width and height(img_w, img_h)
# I also changed the images to an array
# Out:
# (4800, 150, 150, 3) (4800,)

# %%
x = X.astype('float32')
x /= 255

#scaler = MinMaxScaler()
#x = scaler.fit_transform(x)

num_classes = 4

labels = keras.utils.to_categorical(y, num_classes)
print(labels[0])
# Out:
# [1. 0. 0. 0.]

# %%
# splitting our dataset into train and test
x_train1, x_test, y_train1, y_test = train_test_split(x, labels, test_size = 0.2, random_state=5)
x_train,x_val,y_train,y_val=train_test_split(x_train1,y_train1,test_size=0.2,random_state=5)


print('Number of train: {}'.format(len(x_train)))
print('Number of validation: {}'.format(len(x_val)))
print('Number of test: {}'.format(len(x_test)))
# Out:
# Number of train: 3072
# Number of validation: 768
# Number of test: 960

# %%
datagen = ImageDataGenerator(
    rotation_range=20.,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=30.,
    zoom_range=0.2,
    horizontal_flip=0.2,
    rescale=None)

datagen.fit(x_train)

# %%
Res11 = tf.keras.applications.ResNet50(input_shape=(150,150,3),include_top=False,weights="imagenet")

# %%
for layer in Res11.layers:
    layer.trainable=False

# %%
# My neural network consists of 3 layers densely connected
# dropout helps prevent over fitting of the model when testing it
model_resnet=Sequential()
model_resnet.add(Res11)
model_resnet.add(Flatten())
model_resnet.add(Dense(128, activation='relu'))
model_resnet.add(Dropout(0.5))
model_resnet.add(Dense(128, activation='relu'))
model_resnet.add(Dropout(0.5))
model_resnet.add(Dense(4, activation='softmax'))
model_resnet.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 5, 5, 2048)        23587712
#
#  flatten_2 (Flatten)         (None, 51200)             0
#
#  dense_6 (Dense)             (None, 128)               6553728
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 30,158,468
# Trainable params: 6,570,756
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
# here i am defining my performance metrics to check the performance of the model
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

Metrics = [
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
lrd = ReduceLROnPlateau(monitor = 'recall',patience = 10,verbose = 1,factor = 0.70, min_lr = 1e-5)
# the above line of code reduces the learning rate when there is no improvement to the metric
# i added this line of code because i trained the model without it and the performance was stagnant
# the performance was stuck on 0.96nnn as the accuracy so i added the line of code to reduce
# the learing rate after two epochs
mcp = ModelCheckpoint('model.h5')
es = EarlyStopping(verbose=1, patience=20

model_resnet.compile(optimizer='adam', loss = tf.keras.losses.CategoricalCrossentropy(),metrics=METRICS)

# %%
# this is where i fit and trained my model
# %time
history=model_resnet.fit(x_train,y_train,validation_data=(x_val,y_val),epochs = 50,verbose = 1, callbacks=[lrd,mcp,es])
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Epoch 1/50
# 96/96 [==============================] - 445s 4s/step - loss: 1.2982 - accuracy: 0.4343 - precision: 0.6562 - recall: 0.2124 - auc: 0.7097 - f1_score: 0.3139 - val_loss: 0.8779 - val_accuracy: 0.6406 - val_precision: 0.9118 - val_recall: 0.4036 - val_auc: 0.8808 - val_f1_score: 0.5549 - lr: 0.0010
# Epoch 2/50
# 96/96 [==============================] - 412s 4s/step - loss: 1.0154 - accuracy: 0.5208 - precision: 0.9019 - recall: 0.2754 - auc: 0.8096 - f1_score: 0.4156 - val_loss: 0.9334 - val_accuracy: 0.5846 - val_precision: 0.9907 - val_recall: 0.2760 - val_auc: 0.8584 - val_f1_score: 0.4266 - lr: 0.0010
# Epoch 3/50
# 96/96 [==============================] - 405s 4s/step - loss: 0.9730 - accuracy: 0.5273 - precision: 0.9196 - recall: 0.2793 - auc: 0.8185 - f1_score: 0.4229 - val_loss: 0.8069 - val_accuracy: 0.6589 - val_precision: 0.9895 - val_recall: 0.3672 - val_auc: 0.9038 - val_f1_score: 0.5293 - lr: 0.0010
# Epoch 4/50
# 96/96 [==============================] - 412s 4s/step - loss: 0.9430 - accuracy: 0.5433 - precision: 0.9283 - recall: 0.2910 - auc: 0.8266 - f1_score: 0.4374 - val_loss: 0.7505 - val_accuracy: 0.6862 - val_precision: 0.9692 - val_recall: 0.4102 - val_auc: 0.9161 - val_f1_score: 0.5705 - lr: 0.0010
# Epoch 5/50
# 96/96 [==============================] - 402s 4s/step - loss: 0.9677 - accuracy: 0.5339 - precision: 0.9229 - recall: 0.2845 - auc: 0.8179 - f1_score: 0.4302 - val_loss: 0.7642 - val_accuracy: 0.6719 - val_precision: 0.9803 - val_recall: 0.3880 - val_auc: 0.9109 - val_f1_score: 0.5489 - lr: 0.0010
# Epoch 6/50
# 96/96 [==============================] - 506s 5s/step - loss: 0.9555 - accuracy: 0.5394 - precision: 0.9270 - recall: 0.2852 - auc: 0.8220 - f1_score: 0.4316 - val_loss: 0.7106 - val_accuracy: 0.6966 - val_precision: 0.9539 - val_recall: 0.4310 - val_auc: 0.9204 - val_f1_score: 0.5885 - lr: 0.0010
# Epoch 7/50
# 96/96 [==============================] - 412s 4s/step - loss: 0.9535 - accuracy: 0.5420 - precision: 0.9212 - recall: 0.2891 - auc: 0.8222 - f1_score: 0.4318 - val_loss: 1.0074 - val_accuracy: 0.4609 - val_precision: 0.9880 - val_recall: 0.2135 - val_auc: 0.7762 - val_f1_score: 0.3456 - lr: 0.0010
# Epoch 8/50
# 96/96 [==============================] - 421s 4s/step - loss: 1.0173 - accuracy: 0.4788 - precision: 0.9471 - recall: 0.2272 - auc: 0.7786 - f1_score: 0.3598 - val_loss: 0.8558 - val_accuracy: 0.6068 - val_precision: 0.9922 - val_recall: 0.3294 - val_auc: 0.8750 - val_f1_score: 0.4883 - lr: 0.0010
# Epoch 9/50
# 96/96 [==============================] - 406s 4s/step - loss: 0.9109 - accuracy: 0.5563 - precision: 0.9393 - recall: 0.3073 - auc: 0.8381 - f1_score: 0.4571 - val_loss: 0.7424 - val_accuracy: 0.6823 - val_precision: 0.9871 - val_recall: 0.3997 - val_auc: 0.9153 - val_f1_score: 0.5626 - lr: 0.0010
# Epoch 10/50
# 96/96 [==============================] - 416s 4s/step - loss: 0.9286 - accuracy: 0.5479 - precision: 0.9423 - recall: 0.2926 - auc: 0.8286 - f1_score: 0.4400 - val_loss: 0.7946 - val_accuracy: 0.6445 - val_precision: 0.9892 - val_recall: 0.3568 - val_auc: 0.8959 - val_f1_score: 0.5167 - lr: 0.0010
# Epoch 11/50
# 96/96 [==============================] - ETA: 0s - loss: 0.9265 - accuracy: 0.5495 - precision: 0.9468 - recall: 0.2952 - auc: 0.8291 - f1_score: 0.4436
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 96/96 [==============================] - 387s 4s/step - loss: 0.9265 - accuracy: 0.5495 - precision: 0.9468 - recall: 0.2952 - auc: 0.8291 - f1_score: 0.4436 - val_loss: 0.7276 - val_accuracy: 0.6979 - val_precision: 0.9722 - val_recall: 0.4102 - val_auc: 0.9198 - val_f1_score: 0.5702 - lr: 0.0010
# Epoch 12/50
# 96/96 [==============================] - 382s 4s/step - loss: 0.8795 - accuracy: 0.5755 - precision: 0.9552 - recall: 0.3122 - auc: 0.8476 - f1_score: 0.4663 - val_loss: 0.6914 - val_accuracy: 0.6914 - val_precision: 0.9687 - val_recall: 0.4427 - val_auc: 0.9222 - val_f1_score: 0.6009 - lr: 7.0000e-04
# Epoch 13/50
# 96/96 [==============================] - 382s 4s/step - loss: 0.8881 - accuracy: 0.5645 - precision: 0.9495 - recall: 0.3122 - auc: 0.8423 - f1_score: 0.4654 - val_loss: 0.6927 - val_accuracy: 0.7057 - val_precision: 0.9021 - val_recall: 0.4440 - val_auc: 0.9208 - val_f1_score: 0.5902 - lr: 7.0000e-04
# Epoch 14/50
# 96/96 [==============================] - 418s 4s/step - loss: 0.8965 - accuracy: 0.5570 - precision: 0.9446 - recall: 0.3050 - auc: 0.8402 - f1_score: 0.4554 - val_loss: 0.6719 - val_accuracy: 0.7096 - val_precision: 0.9475 - val_recall: 0.4466 - val_auc: 0.9286 - val_f1_score: 0.6004 - lr: 7.0000e-04
# Epoch 15/50
# 96/96 [==============================] - 413s 4s/step - loss: 0.8909 - accuracy: 0.5762 - precision: 0.9475 - recall: 0.3112 - auc: 0.8419 - f1_score: 0.4623 - val_loss: 0.6812 - val_accuracy: 0.6992 - val_precision: 0.9712 - val_recall: 0.4388 - val_auc: 0.9248 - val_f1_score: 0.5980 - lr: 7.0000e-04
# Epoch 16/50
# 96/96 [==============================] - 424s 4s/step - loss: 0.8893 - accuracy: 0.5671 - precision: 0.9436 - recall: 0.3158 - auc: 0.8455 - f1_score: 0.4685 - val_loss: 0.6857 - val_accuracy: 0.7096 - val_precision: 0.9544 - val_recall: 0.4362 - val_auc: 0.9262 - val_f1_score: 0.5930 - lr: 7.0000e-04
# Epoch 17/50
# 96/96 [==============================] - 384s 4s/step - loss: 0.8678 - accuracy: 0.5837 - precision: 0.9584 - recall: 0.3223 - auc: 0.8507 - f1_score: 0.4755 - val_loss: 0.6785 - val_accuracy: 0.7070 - val_precision: 0.9630 - val_recall: 0.4401 - val_auc: 0.9268 - val_f1_score: 0.5981 - lr: 7.0000e-04
# Epoch 18/50
# 96/96 [==============================] - 385s 4s/step - loss: 0.8884 - accuracy: 0.5612 - precision: 0.9586 - recall: 0.3089 - auc: 0.8407 - f1_score: 0.4618 - val_loss: 0.6719 - val_accuracy: 0.7031 - val_precision: 0.9552 - val_recall: 0.4440 - val_auc: 0.9263 - val_f1_score: 0.5998 - lr: 7.0000e-04
# Epoch 19/50
# 96/96 [==============================] - 385s 4s/step - loss: 0.8754 - accuracy: 0.5713 - precision: 0.9547 - recall: 0.3154 - auc: 0.8458 - f1_score: 0.4686 - val_loss: 0.7067 - val_accuracy: 0.6914 - val_precision: 0.9848 - val_recall: 0.4206 - val_auc: 0.9218 - val_f1_score: 0.5823 - lr: 7.0000e-04
# Epoch 20/50
# 96/96 [==============================] - 404s 4s/step - loss: 0.8664 - accuracy: 0.5798 - precision: 0.9557 - recall: 0.3232 - auc: 0.8525 - f1_score: 0.4761 - val_loss: 0.6872 - val_accuracy: 0.7083 - val_precision: 0.9739 - val_recall: 0.4375 - val_auc: 0.9258 - val_f1_score: 0.5970 - lr: 7.0000e-04
# Epoch 21/50
# 96/96 [==============================] - ETA: 0s - loss: 0.8943 - accuracy: 0.5752 - precision: 0.9566 - recall: 0.3083 - auc: 0.8412 - f1_score: 0.4592
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# 96/96 [==============================] - 381s 4s/step - loss: 0.8943 - accuracy: 0.5752 - precision: 0.9566 - recall: 0.3083 - auc: 0.8412 - f1_score: 0.4592 - val_loss: 0.7469 - val_accuracy: 0.6719 - val_precision: 0.9866 - val_recall: 0.3841 - val_auc: 0.9109 - val_f1_score: 0.5454 - lr: 7.0000e-04
# Epoch 22/50
# 96/96 [==============================] - 403s 4s/step - loss: 0.8576 - accuracy: 0.5817 - precision: 0.9638 - recall: 0.3206 - auc: 0.8540 - f1_score: 0.4751 - val_loss: 0.6802 - val_accuracy: 0.7005 - val_precision: 0.9765 - val_recall: 0.4336 - val_auc: 0.9247 - val_f1_score: 0.5945 - lr: 4.9000e-04
# Epoch 23/50
# 96/96 [==============================] - 464s 5s/step - loss: 0.8673 - accuracy: 0.5814 - precision: 0.9638 - recall: 0.3206 - auc: 0.8495 - f1_score: 0.4749 - val_loss: 0.7227 - val_accuracy: 0.6784 - val_precision: 0.9874 - val_recall: 0.4076 - val_auc: 0.9150 - val_f1_score: 0.5698 - lr: 4.9000e-04
# Epoch 24/50
# 96/96 [==============================] - 383s 4s/step - loss: 0.8713 - accuracy: 0.5732 - precision: 0.9659 - recall: 0.3132 - auc: 0.8461 - f1_score: 0.4669 - val_loss: 0.6995 - val_accuracy: 0.6862 - val_precision: 0.9818 - val_recall: 0.4219 - val_auc: 0.9214 - val_f1_score: 0.5835 - lr: 4.9000e-04
# Epoch 25/50
# 96/96 [==============================] - 402s 4s/step - loss: 0.8482 - accuracy: 0.5843 - precision: 0.9709 - recall: 0.3258 - auc: 0.8562 - f1_score: 0.4837 - val_loss: 0.6519 - val_accuracy: 0.7174 - val_precision: 0.9243 - val_recall: 0.4609 - val_auc: 0.9301 - val_f1_score: 0.6082 - lr: 4.9000e-04
# Epoch 26/50
# 96/96 [==============================] - 495s 5s/step - loss: 0.8593 - accuracy: 0.5794 - precision: 0.9639 - recall: 0.3216 - auc: 0.8544 - f1_score: 0.4773 - val_loss: 0.6700 - val_accuracy: 0.7227 - val_precision: 0.9600 - val_recall: 0.4375 - val_auc: 0.9284 - val_f1_score: 0.5954 - lr: 4.9000e-04
# Epoch 27/50
# 96/96 [==============================] - 521s 5s/step - loss: 0.8531 - accuracy: 0.5872 - precision: 0.9616 - recall: 0.3258 - auc: 0.8551 - f1_score: 0.4819 - val_loss: 0.7290 - val_accuracy: 0.6771 - val_precision: 0.9837 - val_recall: 0.3932 - val_auc: 0.9135 - val_f1_score: 0.5541 - lr: 4.9000e-04
# Epoch 28/50
# 96/96 [==============================] - 460s 5s/step - loss: 0.8620 - accuracy: 0.5713 - precision: 0.9496 - recall: 0.3187 - auc: 0.8500 - f1_score: 0.4717 - val_loss: 0.7051 - val_accuracy: 0.6849 - val_precision: 0.9846 - val_recall: 0.4154 - val_auc: 0.9196 - val_f1_score: 0.5774 - lr: 4.9000e-04
# Epoch 29/50
# 96/96 [==============================] - 408s 4s/step - loss: 0.8692 - accuracy: 0.5726 - precision: 0.9612 - recall: 0.3148 - auc: 0.8473 - f1_score: 0.4683 - val_loss: 0.6587 - val_accuracy: 0.7266 - val_precision: 0.9602 - val_recall: 0.4401 - val_auc: 0.9316 - val_f1_score: 0.5979 - lr: 4.9000e-04
# Epoch 30/50
# 96/96 [==============================] - 401s 4s/step - loss: 0.8760 - accuracy: 0.5723 - precision: 0.9611 - recall: 0.3138 - auc: 0.8447 - f1_score: 0.4685 - val_loss: 0.6520 - val_accuracy: 0.7174 - val_precision: 0.9666 - val_recall: 0.4518 - val_auc: 0.9306 - val_f1_score: 0.6096 - lr: 4.9000e-04
# Epoch 31/50
# 96/96 [==============================] - ETA: 0s - loss: 0.8704 - accuracy: 0.5778 - precision: 0.9719 - recall: 0.3154 - auc: 0.8485 - f1_score: 0.4704
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00034300000406801696.
# 96/96 [==============================] - 404s 4s/step - loss: 0.8704 - accuracy: 0.5778 - precision: 0.9719 - recall: 0.3154 - auc: 0.8485 - f1_score: 0.4704 - val_loss: 0.6597 - val_accuracy: 0.7188 - val_precision: 0.9712 - val_recall: 0.4388 - val_auc: 0.9310 - val_f1_score: 0.5986 - lr: 4.9000e-04
# Epoch 32/50
# 96/96 [==============================] - 456s 5s/step - loss: 0.8553 - accuracy: 0.5798 - precision: 0.9657 - recall: 0.3206 - auc: 0.8527 - f1_score: 0.4754 - val_loss: 0.6892 - val_accuracy: 0.7018 - val_precision: 0.9820 - val_recall: 0.4258 - val_auc: 0.9254 - val_f1_score: 0.5875 - lr: 3.4300e-04
# Epoch 33/50
# 96/96 [==============================] - 498s 5s/step - loss: 0.8633 - accuracy: 0.5742 - precision: 0.9720 - recall: 0.3164 - auc: 0.8497 - f1_score: 0.4696 - val_loss: 0.6709 - val_accuracy: 0.7031 - val_precision: 0.9739 - val_recall: 0.4375 - val_auc: 0.9261 - val_f1_score: 0.5976 - lr: 3.4300e-04
# Epoch 34/50
# 96/96 [==============================] - 503s 5s/step - loss: 0.8476 - accuracy: 0.5804 - precision: 0.9752 - recall: 0.3203 - auc: 0.8552 - f1_score: 0.4775 - val_loss: 0.6769 - val_accuracy: 0.7018 - val_precision: 0.9705 - val_recall: 0.4284 - val_auc: 0.9256 - val_f1_score: 0.5882 - lr: 3.4300e-04
# Epoch 35/50
# 96/96 [==============================] - 408s 4s/step - loss: 0.8561 - accuracy: 0.5778 - precision: 0.9548 - recall: 0.3229 - auc: 0.8526 - f1_score: 0.4774 - val_loss: 0.6777 - val_accuracy: 0.6914 - val_precision: 0.9763 - val_recall: 0.4297 - val_auc: 0.9236 - val_f1_score: 0.5902 - lr: 3.4300e-04
# Epoch 36/50
# 96/96 [==============================] - 437s 5s/step - loss: 0.8493 - accuracy: 0.5778 - precision: 0.9725 - recall: 0.3219 - auc: 0.8552 - f1_score: 0.4776 - val_loss: 0.6792 - val_accuracy: 0.7005 - val_precision: 0.9792 - val_recall: 0.4284 - val_auc: 0.9248 - val_f1_score: 0.5895 - lr: 3.4300e-04
# Epoch 37/50
# 96/96 [==============================] - 371s 4s/step - loss: 0.8544 - accuracy: 0.5846 - precision: 0.9774 - recall: 0.3236 - auc: 0.8535 - f1_score: 0.4799 - val_loss: 0.6535 - val_accuracy: 0.7096 - val_precision: 0.9744 - val_recall: 0.4466 - val_auc: 0.9290 - val_f1_score: 0.6058 - lr: 3.4300e-04
# Epoch 38/50
# 96/96 [==============================] - 363s 4s/step - loss: 0.8626 - accuracy: 0.5778 - precision: 0.9768 - recall: 0.3158 - auc: 0.8502 - f1_score: 0.4713 - val_loss: 0.6493 - val_accuracy: 0.7214 - val_precision: 0.9745 - val_recall: 0.4479 - val_auc: 0.9308 - val_f1_score: 0.6072 - lr: 3.4300e-04
# Epoch 39/50
# 96/96 [==============================] - 359s 4s/step - loss: 0.8272 - accuracy: 0.5928 - precision: 0.9770 - recall: 0.3324 - auc: 0.8608 - f1_score: 0.4896 - val_loss: 0.6520 - val_accuracy: 0.7135 - val_precision: 0.9715 - val_recall: 0.4440 - val_auc: 0.9308 - val_f1_score: 0.6035 - lr: 3.4300e-04
# Epoch 40/50
# 96/96 [==============================] - 362s 4s/step - loss: 0.8639 - accuracy: 0.5742 - precision: 0.9652 - recall: 0.3158 - auc: 0.8490 - f1_score: 0.4692 - val_loss: 0.6951 - val_accuracy: 0.6862 - val_precision: 0.9794 - val_recall: 0.4323 - val_auc: 0.9192 - val_f1_score: 0.5933 - lr: 3.4300e-04
# Epoch 41/50
# 96/96 [==============================] - ETA: 0s - loss: 0.8535 - accuracy: 0.5863 - precision: 0.9687 - recall: 0.3226 - auc: 0.8547 - f1_score: 0.4792
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00024009999469853935.
# 96/96 [==============================] - 241s 3s/step - loss: 0.8535 - accuracy: 0.5863 - precision: 0.9687 - recall: 0.3226 - auc: 0.8547 - f1_score: 0.4792 - val_loss: 0.6430 - val_accuracy: 0.7396 - val_precision: 0.9315 - val_recall: 0.4779 - val_auc: 0.9354 - val_f1_score: 0.6266 - lr: 3.4300e-04
# Epoch 42/50
# 96/96 [==============================] - 196s 2s/step - loss: 0.8585 - accuracy: 0.5801 - precision: 0.9742 - recall: 0.3190 - auc: 0.8514 - f1_score: 0.4741 - val_loss: 0.6545 - val_accuracy: 0.7188 - val_precision: 0.9719 - val_recall: 0.4505 - val_auc: 0.9316 - val_f1_score: 0.6086 - lr: 2.4010e-04
# Epoch 43/50
# 96/96 [==============================] - 192s 2s/step - loss: 0.8502 - accuracy: 0.5814 - precision: 0.9736 - recall: 0.3239 - auc: 0.8539 - f1_score: 0.4799 - val_loss: 0.6501 - val_accuracy: 0.7096 - val_precision: 0.9744 - val_recall: 0.4466 - val_auc: 0.9306 - val_f1_score: 0.6052 - lr: 2.4010e-04
# Epoch 44/50
# 96/96 [==============================] - 187s 2s/step - loss: 0.8714 - accuracy: 0.5729 - precision: 0.9624 - recall: 0.3164 - auc: 0.8478 - f1_score: 0.4709 - val_loss: 0.6573 - val_accuracy: 0.7201 - val_precision: 0.9691 - val_recall: 0.4492 - val_auc: 0.9308 - val_f1_score: 0.6074 - lr: 2.4010e-04
# Epoch 45/50
# 96/96 [==============================] - 191s 2s/step - loss: 0.8504 - accuracy: 0.5863 - precision: 0.9747 - recall: 0.3265 - auc: 0.8557 - f1_score: 0.4852 - val_loss: 0.6690 - val_accuracy: 0.7083 - val_precision: 0.9713 - val_recall: 0.4401 - val_auc: 0.9279 - val_f1_score: 0.5991 - lr: 2.4010e-04
# Epoch 46/50
# 96/96 [==============================] - 188s 2s/step - loss: 0.8260 - accuracy: 0.5928 - precision: 0.9664 - recall: 0.3369 - auc: 0.8625 - f1_score: 0.4936 - val_loss: 0.6638 - val_accuracy: 0.7148 - val_precision: 0.9688 - val_recall: 0.4440 - val_auc: 0.9296 - val_f1_score: 0.6024 - lr: 2.4010e-04
# Epoch 47/50
# 96/96 [==============================] - 229s 2s/step - loss: 0.8347 - accuracy: 0.5915 - precision: 0.9634 - recall: 0.3346 - auc: 0.8613 - f1_score: 0.4916 - val_loss: 0.6704 - val_accuracy: 0.7083 - val_precision: 0.9512 - val_recall: 0.4570 - val_auc: 0.9273 - val_f1_score: 0.6121 - lr: 2.4010e-04
# Epoch 48/50
# 96/96 [==============================] - 204s 2s/step - loss: 0.8436 - accuracy: 0.5970 - precision: 0.9680 - recall: 0.3346 - auc: 0.8573 - f1_score: 0.4914 - val_loss: 0.6444 - val_accuracy: 0.7279 - val_precision: 0.9497 - val_recall: 0.4674 - val_auc: 0.9334 - val_f1_score: 0.6204 - lr: 2.4010e-04
# Epoch 49/50
# 96/96 [==============================] - 214s 2s/step - loss: 0.8299 - accuracy: 0.5977 - precision: 0.9560 - recall: 0.3395 - auc: 0.8622 - f1_score: 0.4943 - val_loss: 0.6448 - val_accuracy: 0.7253 - val_precision: 0.9671 - val_recall: 0.4596 - val_auc: 0.9334 - val_f1_score: 0.6171 - lr: 2.4010e-04
# Epoch 50/50
# 96/96 [==============================] - 209s 2s/step - loss: 0.8360 - accuracy: 0.6090 - precision: 0.9538 - recall: 0.3496 - auc: 0.8626 - f1_score: 0.5066 - val_loss: 0.6299 - val_accuracy: 0.7500 - val_precision: 0.9447 - val_recall: 0.4896 - val_auc: 0.9394 - val_f1_score: 0.6397 - lr: 2.4010e-04

# %%
Test_data = model_Inception.evaluate(x_test, y_test)
# Out:
# 30/30 [==============================] - 60s 2s/step - loss: 1.4304 - accuracy: 0.4676 - precision: 0.9447 - recall: 0.2176 - auc: 0.7400 - f1_score: 0.0000e+00

# %%
#loss
plt.style.use("ggplot")
plt.plot(history.history['loss'], 'go--', c = "blue", label='Train loss')
plt.plot(history.history['val_loss'], 'go--', c = "red", label='Val loss')
plt.title('ResNet50 Model For loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

#accuracies
plt.plot(history.history['accuracy'], 'go--', c = "blue", label='Train accuracy')
plt.plot(history.history['val_accuracy'], 'go--', c = "red", label='Val accuracy')
plt.title('ResNet50 Model For Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.savefig('AccuracyVal_accuracy')


plt.plot(history.history['precision'], 'go--', c = "blue", label='Precision')
plt.plot(history.history['val_precision'], 'go--', c = "red", label='Val_precision')
plt.title('ResNet50 Model For Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend() 
plt.show()
plt.savefig('Precision_Scores')

         
plt.plot(history.history['recall'], 'go--', c = "blue", label='Recall')
plt.plot(history.history['val_recall'], 'go--', c = "red", label='Val_Recall')
plt.title('ResNet50 Model For Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.savefig('Recall_Scores')



plt.plot(history.history['f1_score'], 'go--', c = "blue", label='F1_score')
plt.plot(history.history['val_f1_score'], 'go--', c = "red", label='Val_F1_score')
plt.title('ResNet50 Model For F1_score')
plt.ylabel('F1_score')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.savefig('F1_Score')




plt.plot(history.history['auc'], 'go--', c = "blue", label='AUC')
plt.plot(history.history['val_auc'], 'go--', c = "red", label='Val_AUC')
plt.title('ResNet50 Model For AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.savefig('AUC')

# %%
acc = history.history['recall']
val_acc = history.history['val_recall']
loss = history.history['precision']
val_loss = history.history['val_precision']
epochs_range = range(len(history.history['val_precision']))
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.scatter(epochs_range, acc, label='Training Recall')
plt.scatter(epochs_range, val_acc, label='Validation Recall')
plt.legend(loc='lower right')
plt.title('ResNet50 Model For Train and Valid Recall')
plt.subplot(1, 2, 2)
plt.scatter(epochs_range, loss, label='Training Precision')
plt.scatter(epochs_range, val_loss, label='Validation Precision')
plt.legend(loc='lower right')
plt.title('ResNet50 Model For Train and Valid Precision')
plt.show()




acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(history.history['val_loss']))
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.scatter(epochs_range, acc, label='Training Accuracy')
plt.scatter(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('ResNet50 Model For Train and Valid Accuracy')
plt.subplot(1, 2, 2)
plt.scatter(epochs_range, loss, label='Training Loss')
plt.scatter(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('ResNet50 Model For Train and Valid Loss')
plt.show()





acc = history.history['f1_score']
val_acc = history.history['val_f1_score']
loss = history.history['auc']
val_loss = history.history['val_auc']
epochs_range = range(len(history.history['val_auc']))
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.scatter(epochs_range, acc, label='Training F1_score')
plt.scatter(epochs_range, val_acc, label='Validation F1_score')
plt.legend(loc='lower right')
plt.title('ResNet50 Model For Train and Valid F1_score')
plt.subplot(1, 2, 2)
plt.scatter(epochs_range, loss, label='Training AUC')
plt.scatter(epochs_range, acc, label='Validation AUC')
plt.legend(loc='lower right')
plt.title('ResNet50 Model For Train and Valid AUC')
plt.show()

# %%
# here i want to define and plot my confusion matrix
# and also my classification report
def plot_confusion_matrix(cm, classes, normalize=True, title='ResNet50 Model Confusion matrix', cmap=plt.cm.Blues):
    
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    
y_pred = (model_resnet.predict(x_test) > 0.5).astype("int32")

y_test_c = np.argmax(y_test, axis=1)
target_names = ["bending", "lying", "sitting", "standing"]

Y_pred = np.argmax(model_resnet.predict(x_test),axis=1)
print('ResNet50 Model Confusion Matrix')
cm = confusion_matrix(y_test_c, Y_pred)
plot_confusion_matrix(cm, target_names, normalize=False, title='ResNet50 Model Confusion Matrix')

print('Classification Report')
print(classification_report(y_test_c, Y_pred, target_names=target_names))
# Out:
# 30/30 [==============================] - 52s 2s/step
# 30/30 [==============================] - 54s 2s/step
# ResNet50 Model Confusion Matrix
# Classification Report
#               precision    recall  f1-score   support
#
#      bending       0.52      0.89      0.65       229
#        lying       0.97      0.92      0.94       242
#      sitting       0.68      0.21      0.32       247
#     standing       0.88      0.94      0.91       242
#
#     accuracy                           0.74       960
#    macro avg       0.76      0.74      0.71       960
# weighted avg       0.76      0.74      0.71       960

# %%
# here i want to define and plot my confusion matrix
# and also my classification report
def plot_confusion_matrix(cm, classes, normalize=True, title='ResNet50 Model Confusion matrix', cmap=plt.cm.Blues):
    
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    
y_pred = (model_resnet.predict(x_test) > 0.5).astype("int32")

y_test_c = np.argmax(y_test, axis=1)
target_names = ["bending", "lying", "sitting", "standing"]

Y_pred = np.argmax(model_resnet.predict(x_test),axis=1)
print('ResNet50 Model Confusion Matrix')
cm = confusion_matrix(y_test_c, Y_pred)
plot_confusion_matrix(cm, target_names, normalize=True, title='ResNet50 Model Confusion Matrix')

print('Classification Report')
print(classification_report(y_test_c, Y_pred, target_names=target_names))
# Out:
# 30/30 [==============================] - 55s 2s/step
# 30/30 [==============================] - 72s 2s/step
# ResNet50 Model Confusion Matrix
# Classification Report
#               precision    recall  f1-score   support
#
#      bending       0.52      0.89      0.65       229
#        lying       0.97      0.92      0.94       242
#      sitting       0.68      0.21      0.32       247
#     standing       0.88      0.94      0.91       242
#
#     accuracy                           0.74       960
#    macro avg       0.76      0.74      0.71       960
# weighted avg       0.76      0.74      0.71       960
